# %%
import sys, os

# Get project root — one level up from 'research_and_analyst'
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(project_root)

print("Project root added to path:", project_root)
# Out:
# Project root added to path: d:\All_Python_Project_ML_DL\LLMOPS_Projects\3rd_prj\automated-research-report-generation

# %%
from research_and_analyst.utils.model_loader import ModelLoader

# %%
model_loader = ModelLoader()
# Out:
# {"timestamp": "2025-10-14T04:43:06.025014Z", "level": "warning", "event": "OPENAI_API_KEY is missing from environment"}
# {"timestamp": "2025-10-14T04:43:06.028392Z", "level": "info", "event": "GOOGLE_API_KEY loaded from environment"}
# {"timestamp": "2025-10-14T04:43:06.032910Z", "level": "info", "event": "GROQ_API_KEY loaded from environment"}
# {"timestamp": "2025-10-14T04:43:06.035755Z", "level": "warning", "event": "ASTRA_DB_API_ENDPOINT is missing from environment"}
# {"timestamp": "2025-10-14T04:43:06.038256Z", "level": "warning", "event": "ASTRA_DB_APPLICATION_TOKEN is missing from environment"}
# {"timestamp": "2025-10-14T04:43:06.042063Z", "level": "warning", "event": "ASTRA_DB_KEYSPACE is missing from environment"}
# {"config_keys": ["astra_db", "embedding_model", "retriever", "llm"], "timestamp": "2025-10-14T04:43:06.050100Z", "level": "info", "event": "YAML config loaded"}

# %%
llm = model_loader.load_llm()
# Out:
# {"provider": "openai", "model": "gpt-4o", "timestamp": "2025-10-14T04:43:55.669373Z", "level": "info", "event": "Loading LLM"}
